# %% [markdown]
# # List of Contents
#
# ## 1: Create Data Dictionaries (to experiment with)
# #### 1a. Import Libraries
# #### 1b. Define Data Dictionaries
# #### 1c. Convert Dictionaries into Dataframe
#
#
# ## 2: Concatenate Dataframes (to experiment with)
#
# ## 3. Merge Dataframes (to experiment with)
#
# ## 4. Merge Instacart Data
# #### 4a Combining df_ords with orders_products_prior
# #### 4b. Export Merged Dataframes as CSV and PKL

# %% [markdown]
# ## 1. Create Data Dictionaries

# %% [markdown]
# #### 1a. Import Libraries

# %%
 # Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 1b. Define Data Dictionaries

# %%
# Define a dictionary containing January 2020 data
data1 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'],
    'purchased_meat':[0, 13, 3, 4],
    'purchased_alcohol':[1, 2, 10, 0],
    'purchased_snacks':[10, 5, 1, 7]}

# %%
# Define a dictionary containing February 2020 data
data2 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Feb-20', 'Feb-20', 'Feb-20', 'Feb-20'],
    'purchased_meat':[0, 10, 5, 3],
    'purchased_alcohol':[2, 4, 14, 0],
    'purchased_snacks':[15, 3, 2, 6]}

# %%
#Convert the dictionary into dataframe
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
df_1 = pd.DataFrame(data2,index=[0, 1, 2, 3])

# %% [markdown]
# #### 1c. Convert Dictionaries into Dataframe

# %%
df
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7

# %%
df_1
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %% [markdown]
# ## 2. Concatenate Dataframes

# %%
frames = [df, df_1]
df_concat = pd.concat(frames)

# %%
# default: Axis = 0 --> this creates a stacked concatenated df
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
# wider df using axis = 1
df_concat = pd.concat(frames, axis = 1)

# %%
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %% [markdown]
# ## 3. Merging

# %%
data3 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'],
    'days_purchased_on':[0, 10, 4, 1]}

df_2 = pd.DataFrame(data3,index=[0, 1, 2, 3])

# %%
df_merged = df.merge(df_2, on = 'customer_id')

# %%
df_merged
# Out:
#   customer_id month_x  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#   month_y  days_purchased_on
# 0  Jan-20                  0
# 1  Jan-20                 10
# 2  Jan-20                  4
# 3  Jan-20                  1

# %%
# Specifying two common columns

df_merged = df.merge(df_2, on = ['customer_id','month'])

# %%
df_merged
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#    days_purchased_on
# 0                  0
# 1                 10
# 2                  4
# 3                  1

# %%
# Checking for Full Match

df_merged = df.merge(df_2, on = ['customer_id', 'month'], indicator = True)

# %%
df_merged
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#    days_purchased_on _merge
# 0                  0   both
# 1                 10   both
# 2                  4   both
# 3                  1   both

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          4
# left_only     0
# right_only    0
# Name: count, dtype: int64

# %%
# Test merge without overwriting
pd.merge(df,df_2, on = ['customer_id', 'month'], indicator = True)
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#    days_purchased_on _merge
# 0                  0   both
# 1                 10   both
# 2                  4   both
# 3                  1   both

# %%
df.merge(df_2, on = ['customer_id', 'month'], how = 'inner')
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#    days_purchased_on
# 0                  0
# 1                 10
# 2                  4
# 3                  1

# %% [markdown]
# ## 4. Merging Instacart Data
#
#
# ### Merge df_ords and df_prods
# There is no common column

# %% [markdown]
# #### 4a Combining df_ords with orders_products_prior
# In order to achieve a common column

# %%
# Importing Datasets

path = r'/Users/tristansavella/Instacart Basket Analysis'

df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'), index_col = False)
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data','orders_wrangled.csv'), index_col = False)

# %%
# Checking Dimensions of df_ords_prior

df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
# Checking df_ords_prior output

df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Checking df_ords shape

df_ords.shape
# Out:
# (3421083, 8)

# %%
# Checking df_ords output

df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           1   2398795        1    prior             2                   3
# 2           2    473747        1    prior             3                   3
# 3           3   2254736        1    prior             4                   4
# 4           4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_passed_since_last_order
# 0                  8                           NaN
# 1                  7                          15.0
# 2                 12                          21.0
# 3                  7                          29.0
# 4                 15                          28.0

# %%
# Merging 2 dfs

df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
# Check Output for df_merged_large

df_merged_large.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           0   2539329        1    prior             1                   2
# 2           0   2539329        1    prior             1                   2
# 3           0   2539329        1    prior             1                   2
# 4           0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_passed_since_last_order  product_id  \
# 0                  8                           NaN         196
# 1                  8                           NaN       14084
# 2                  8                           NaN       12427
# 3                  8                           NaN       26088
# 4                  8                           NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
# Checking for Full Match Between 2 dfs

df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# #### 4b. Export Merged Dataframes as CSV and PKL

# %%
# Export data to csv

df_merged_large.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.csv'))

# %%
# Export data to pkl

df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
